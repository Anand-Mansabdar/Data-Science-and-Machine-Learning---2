# %%
import nltk

# %%
corpus = """Good morning everyone,
Today, I don’t want to talk to you about success.
I don’t want to talk about failure either.
I want to talk to you about the space between the two — the part no one posts on LinkedIn, no one puts on Instagram, and no one applauds.
That space is called the journey.
You see, we live in a world that celebrates outcomes.
We clap for degrees, titles, salaries, rankings, followers, and results.
But we rarely talk about the nights of doubt, the confusion, the fear of being left behind, and the quiet resilience it takes to keep going when nobody is watching.
Every single person sitting here today is on a different timeline.
And yet, we constantly compare our Chapter 3 with someone else’s Chapter 20.
Let me tell you something important:
Life is not a race. It is a process.
Some people discover their purpose early.
Some discover it late.
Some change it multiple times.
None of that makes you behind.
What does put you behind is quitting on yourself because your progress doesn’t look like someone else’s highlight reel.
You will have moments where you question your abilities.
Moments where you wonder if you chose the right path.
Moments where you feel like everyone else has figured it out except you.
Let me be honest with you — most people are figuring it out as they go.
Confidence is not clarity.
Often, it’s just courage wearing a calm face.
The truth is, growth is uncomfortable.
Transformation is messy.
And progress is often invisible while it’s happening.
When you plant a seed, you don’t dig it up every day to check if it’s growing.
You water it.
You protect it.
You trust the process.
It tells you what didn’t work.
It sharpens your judgment.
It humbles your ego and strengthens your character.
The only real failure is refusing to learn.
So walk out of this room with patience for yourself.
With belief in your ability to grow.
And with the courage to continue, even when the path feels unclear.
Your story is still being written.
And the next chapter is waiting for you to show up.
Thank you."""

# %%
sentences = nltk.sent_tokenize(corpus)

# %%
sentences
# Out:
# ['Good morning everyone,\nToday, I don’t want to talk to you about success.',
#  'I don’t want to talk about failure either.',
#  'I want to talk to you about the space between the two — the part no one posts on LinkedIn, no one puts on Instagram, and no one applauds.',
#  'That space is called the journey.',
#  'You see, we live in a world that celebrates outcomes.',
#  'We clap for degrees, titles, salaries, rankings, followers, and results.',
#  'But we rarely talk about the nights of doubt, the confusion, the fear of being left behind, and the quiet resilience it takes to keep going when nobody is watching.',
#  'Every single person sitting here today is on a different timeline.',
#  'And yet, we constantly compare our Chapter 3 with someone else’s Chapter 20.',
#  'Let me tell you something important:\nLife is not a race.',
#  'It is a process.',
#  'Some people discover their purpose early.',
#  'Some discover it late.',
#  'Some change it multiple times.',
#  'None of that makes you behind.',
#  'What does put you behind is quitting on yourself because your progress doesn’t look like someone else’s highlight reel.',
#  'You will have moments where you question your abilities.',
#  'Moments where you wonder if you chose the right path.',
#  'Moments where you feel like everyone else has figured it out except you.',
#  'Let me be honest with you — most people are figuring it out as they go.',
#  'Confidence is not clarity.',
#  'Often, it’s just courage wearing a calm face.',
#  'The truth is, growth is uncomfortable.',
#  'Transformation is messy.',
#  'And progress is often invisible while it’s happening.',
#  'When you plant a seed, you don’t dig it up every day to check if it’s growing.',
#  'You water it.',
#  'You protect it.',
#  'You trust the process.',
#  'It tells you what didn’t work.',
#  'It sharpens your judgment.',
#  'It humbles your ego and strengthens your character.',
#  'The only real failure is refusing to learn.',
#  'So walk out of this room with patience for yourself.',
#  'With belief in your ability to grow.',
#  'And with the courage to continue, even when the path feels unclear.',
#  'Your story is still being written.',
#  'And the next chapter is waiting for you to show up.',
#  'Thank you.']

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
nltk.download('averaged_perceptron_tagger_eng')

for i in range(len(sentences)):
  words = nltk.word_tokenize(sentences[i])
  words = [word for word in words if word not in set(stopwords.words("english"))]
  pos_tags = nltk.pos_tag(words)
  print(pos_tags)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anand\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\anand\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [('Good', 'JJ'), ('morning', 'NN'), ('everyone', 'NN'), (',', ','), ('Today', 'NNP'), (',', ','), ('I', 'PRP'), ('’', 'VBP'), ('want', 'JJ'), ('talk', 'NN'), ('success', 'NN'), ('.', '.')]
# [('I', 'PRP'), ('’', 'VBP'), ('want', 'JJ'), ('talk', 'NN'), ('failure', 'NN'), ('either', 'RB'), ('.', '.')]
# [('I', 'PRP'), ('want', 'VBP'), ('talk', 'JJ'), ('space', 'NN'), ('two', 'CD'), ('—', 'JJ'), ('part', 'NN'), ('one', 'CD'), ('posts', 'VBZ'), ('LinkedIn', 'NNP'), (',', ','), ('one', 'CD'), ('puts', 'VBZ'), ('Instagram', 'NNP'), (',', ','), ('one', 'CD'), ('applauds', 'NN'), ('.', '.')]
# [('That', 'DT'), ('space', 'NN'), ('called', 'VBD'), ('journey', 'NN'), ('.', '.')]
# [('You', 'PRP'), ('see', 'VBP'), (',', ','), ('live', 'JJ'), ('world', 'NN'), ('celebrates', 'VBZ'), ('outcomes', 'NNS'), ('.', '.')]
# [('We', 'PRP'), ('clap', 'VBP'), ('degrees', 'NNS'), (',', ','), ('titles', 'NNS'), (',', ','), ('salaries', 'NNS'), (',', ','), ('rankings', 'NNS'), (',', ','), ('followers', 'NNS'), (',', ','), ('results', 'NNS'), ('.', '.')]
# [('But', 'CC'), ('rarely', 'RB'), ('talk', 'VB'), ('nights', 'NNS'), ('doubt', 'NN'), (',', ','), ('confusion', 'NN'), (',', ','), ('fear', 'NN'), ('left', 'VBD'), ('behind', 'RP'), (',', ','), ('quiet', 'JJ'), ('resilience', 'NN'), ('takes', 'VBZ'), ('keep', 'VB'), ('going', 'VBG'), ('nobody', 'NN'), ('watching', 'NN'), ('.', '.')]
# [('Every', 'DT'), ('single', 'JJ'), ('person', 'NN'), ('sitting', 'VBG'), ('today', 'NN'), ('different', 'JJ'), ('timeline', 'NN'), ('.', '.')]
# [('And', 'CC'), ('yet', 'RB'), (',', ','), ('constantly', 'RB'), ('compare', 'VBP'), ('Chapter', 'NNP'), ('3', 'CD'), ('someone', 'NN'), ('else', 'RB'), ('’', 'NNP'), ('Chapter', 'NNP'), ('20', 'CD'), ('.', '.')]
# [('Let', 'VB'), ('tell', 'VB'), ('something', 'NN'), ('important', 'JJ'), (':', ':'), ('Life', 'JJ'), ('race', 'NN'), ('.', '.')]
# [('It', 'PRP'), ('process', 'NN'), ('.', '.')]
# [('Some', 'DT'), ('people', 'NNS'), ('discover', 'VBP'), ('purpose', 'RB'), ('early', 'JJ'), ('.', '.')]
# [('Some', 'DT'), ('discover', 'NN'), ('late', 'RB'), ('.', '.')]
# [('Some', 'DT'), ('change', 'NN'), ('multiple', 'JJ'), ('times', 'NNS'), ('.', '.')]
# [('None', 'NN'), ('makes', 'VBZ'), ('behind', 'IN'), ('.', '.')]
# [('What', 'WP'), ('put', 'VBD'), ('behind', 'RP'), ('quitting', 'VBG'), ('progress', 'NN'), ('’', 'JJ'), ('look', 'NN'), ('like', 'IN'), ('someone', 'NN'), ('else', 'RB'), ('’', 'NNP'), ('highlight', 'NN'), ('reel', 'NN'), ('.', '.')]
# [('You', 'PRP'), ('moments', 'NNS'), ('question', 'NN'), ('abilities', 'NNS'), ('.', '.')]
# [('Moments', 'NNS'), ('wonder', 'VBP'), ('chose', 'JJ'), ('right', 'JJ'), ('path', 'NN'), ('.', '.')]
# [('Moments', 'NNS'), ('feel', 'VBP'), ('like', 'IN'), ('everyone', 'NN'), ('else', 'RB'), ('figured', 'VBD'), ('except', 'IN'), ('.', '.')]
# [('Let', 'VB'), ('honest', 'JJS'), ('—', 'JJ'), ('people', 'NNS'), ('figuring', 'VBG'), ('go', 'NN'), ('.', '.')]
# [('Confidence', 'NN'), ('clarity', 'NN'), ('.', '.')]
# [('Often', 'RB'), (',', ','), ('’', 'JJ'), ('courage', 'NN'), ('wearing', 'VBG'), ('calm', 'JJ'), ('face', 'NN'), ('.', '.')]
# [('The', 'DT'), ('truth', 'NN'), (',', ','), ('growth', 'NN'), ('uncomfortable', 'JJ'), ('.', '.')]
# [('Transformation', 'NN'), ('messy', 'NN'), ('.', '.')]
# [('And', 'CC'), ('progress', 'NN'), ('often', 'RB'), ('invisible', 'JJ'), ('’', 'JJ'), ('happening', 'NN'), ('.', '.')]
# [('When', 'WRB'), ('plant', 'NN'), ('seed', 'NN'), (',', ','), ('’', 'NNP'), ('dig', 'NN'), ('every', 'DT'), ('day', 'NN'), ('check', 'VB'), ('’', 'IN'), ('growing', 'VBG'), ('.', '.')]
# [('You', 'PRP'), ('water', 'NN'), ('.', '.')]
# [('You', 'PRP'), ('protect', 'VBP'), ('.', '.')]
# [('You', 'PRP'), ('trust', 'VBP'), ('process', 'NN'), ('.', '.')]
# [('It', 'PRP'), ('tells', 'VBZ'), ('’', 'JJ'), ('work', 'NN'), ('.', '.')]
# [('It', 'PRP'), ('sharpens', 'VBZ'), ('judgment', 'NN'), ('.', '.')]
# [('It', 'PRP'), ('humbles', 'VBZ'), ('ego', 'JJ'), ('strengthens', 'NNS'), ('character', 'NN'), ('.', '.')]
# [('The', 'DT'), ('real', 'JJ'), ('failure', 'NN'), ('refusing', 'VBG'), ('learn', 'NN'), ('.', '.')]
# [('So', 'RB'), ('walk', 'JJ'), ('room', 'NN'), ('patience', 'NN'), ('.', '.')]
# [('With', 'IN'), ('belief', 'JJ'), ('ability', 'NN'), ('grow', 'NN'), ('.', '.')]
# [('And', 'CC'), ('courage', 'NN'), ('continue', 'VBP'), (',', ','), ('even', 'RB'), ('path', 'NN'), ('feels', 'NNS'), ('unclear', 'VBP'), ('.', '.')]
# [('Your', 'PRP$'), ('story', 'NN'), ('still', 'RB'), ('written', 'VBN'), ('.', '.')]
# [('And', 'CC'), ('next', 'JJ'), ('chapter', 'NN'), ('waiting', 'VBG'), ('show', 'NN'), ('.', '.')]
# [('Thank', 'NNP'), ('.', '.')]

# %%
print(nltk.pos_tag("Taj Mahal is a beautiful monument".split()))
# Out:
# [('Taj', 'NNP'), ('Mahal', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('monument', 'NN')]

# %%
print(nltk.pos_tag("Virat Kohli is the best cricketer of the current generation!!!".split()))
# Out:
# [('Virat', 'NNP'), ('Kohli', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('best', 'JJS'), ('cricketer', 'NN'), ('of', 'IN'), ('the', 'DT'), ('current', 'JJ'), ('generation!!!', 'NN')]
